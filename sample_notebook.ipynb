# %% [markdown]
# ## Section 1: Basic Python

# %%
# Simple Python code
name = "Jupyter Notebook"
version = 7.0

print(f"Welcome to {name} v{version}!")

# %% [markdown]
# ## Section 2: Data Analysis Example

# %%
import numpy as np
import pandas as pd

# Create sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [95, 87, 92, 88],
    'Grade': ['A', 'B', 'A', 'B']
}

df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ## Section 3: Mathematical Expressions
#
# The quadratic formula is:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
#
# Where $a$, $b$, and $c$ are coefficients.

# %%
# Calculate average score
average_score = df['Score'].mean()
print(f"Average Score: {average_score:.2f}")

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates various notebook features:
# - Markdown cells with formatting
# - Code execution
# - Data manipulation
# - Mathematical expressions
#
# Use the converter to export this to PDF!
